# %% [markdown]
# # 廣韻的例外

# %% [markdown]
# [返回 GitHub 頁面](https://github.com/sgalal/Guangyun)

# %%
import pandas
import sqlite3

# %%
conn = sqlite3.connect('../data.sqlite3')

# %%
pandas.options.display.max_rows = None
pandas.options.display.max_columns = None
pandas.options.display.max_colwidth = -1

# %% [markdown]
# ## 沒有反切的小韻

# %%
pandas.read_sql_query('''SELECT 小韻號, 音韻地位, 上字, 下字,
GROUP_CONCAT(字頭, '') AS 字頭
FROM 廣韻字頭全
WHERE 上字 IS NULL
OR 上字 IS NULL
GROUP BY 小韻號;''', conn)
# Out:
#     小韻號   音韻地位    上字    下字     字頭
# 0  1919  章開三蒸上  None  None  拯抍撜𨋬氶
# 1  3177  影開二銜去  None  None  𪒠

# %% [markdown]
# ## 具有相同音韻地位的小韻

# %%
pandas.read_sql_query('''SELECT 音韻地位,
group_concat(小韻全名) AS 小韻全名
FROM 廣韻小韻全
GROUP BY 音韻地位
HAVING count(*) > 1
ORDER BY 小韻號;''', conn)
# Out:
#       音韻地位                     小韻全名
# 0   精開三支平   114貲小韻,133厜小韻
# 1   精合三支平   135劑小韻,138䮔小韻
# 2   書開三之平   193詩小韻,210䀵小韻
# 3   溪開三之平   195欺小韻,209抾小韻
# 4   溪開二刪平   551馯小韻,552豻小韻
# 5   溪開二麻平   798䶗小韻,804𣘟小韻
# 6   幫開二耕平   892浜小韻,902繃小韻
# 7   溪開三尤平   996恘小韻,1002丘小韻
# 8   從開一談平   1094慙小韻,1097𩈻小韻
# 9   章開三鍾上   1171腫小韻,1191𢃭小韻
# 10  章開三脂上   1251旨小韻,1281𧿲小韻
# 11  滂開一咍上   1452啡小韻,1458俖小韻
# 12  以開一咍上   1460佁小韻,1464䑂小韻
# 13  日合三諄上   1487蝡小韻,1492𣯍小韻
# 14  知開二麻上   1789觰小韻,1792䋾小韻
# 15  初開三陽上   1807磢小韻,1831䫪小韻
# 16  見合三陽上   1816獷小韻,1829臩小韻
# 17  滂開三尤上   1950㤱小韻,1954秠小韻
# 18  曉開二咸上   2073闞小韻,2076喊小韻
# 19  曉合三脂A去  2234䁤小韻,2245侐小韻
# 20  曉合三廢去   2421䂕小韻,2548喙小韻
# 21  清合一泰去   2444襊小韻,2452𦦣小韻
# 22  幫開二佳去   2462庍小韻,2470㠔小韻
# 23  匣合一灰去   2520潰小韻,2527蚚小韻
# 24  滂合三元去   2601嬔小韻,2607𣀔小韻
# 25  清合一戈去   2843剉小韻,2849諎小韻,2855磋小韻
# 26  見開四添去   3148趝小韻,3152兼小韻
# 27  溪開三嚴去   3157㪁小韻,3181欠小韻
# 28  知開三眞入   3300窒小韻,3321蛭小韻
# 29  崇開三臻入   3312𪗨小韻,3339𪗨小韻
# 30  知合三諄入   3318茁小韻,3331㤕小韻
# 31  透合一魂入   3373𣅝小韻,3377宊小韻
# 32  昌合三仙入   3513歠小韻,3534啜小韻
# 33  知開三蒸入   3698陟小韻,3722𡮞小韻
# 34  影開一覃入   3787姶小韻,3792唈小韻
# 35  見開一談入   3803䫦小韻,3807砝小韻
# 36  心開四添入   3836燮小韻,3842䢡小韻

# %% [markdown]
# BYVoid[《廣韻中的重紐與重紐歸類問題》](https://www.byvoid.com/blog/kuangx-yonh-dryung-nriux)
#
# > 除了上述的重紐現象外，廣韻中還有一些「後增字」。如《廣韻》中有小韻「辟」必益切，又有小韻「碧」彼役切。根據系聯兩個小韻的聲韻地位完全相同，理應歸類爲一個小韻纔對。這種情況不同於重紐，因爲在《刊謬補缺切韻》中，沒有「碧」這個字，而在《唐韻》殘卷中，有「碧色也說文石文美者方彳反一加」，可見「碧」這個字是 **後世新加入的**。由於「碧」所用反切和「辟」不同，《廣韻》編輯者就把「碧」放在了相同韻目的最後，這樣就重出了一個小韻。這種現象的特點是，重複的小韻在前世韻書中沒有出現，且一般只附在《廣韻》一個韻目的最後，零星而不成系統。

# %% [markdown]
# ## 同一個音韻地位存在兩個一樣的字

# %%
pandas.read_sql_query('''SELECT 字頭, 音韻地位,
group_concat(小韻號 || '-' || 小韻內字序) AS '小韻號-小韻內字序'
FROM 廣韻字頭全
GROUP BY 音韻地位, 字頭
HAVING count(*) > 1;''', conn)
# Out:
#   字頭   音韻地位       小韻號-小韻內字序
# 0  䱱  定開四齊平  301-29,301-38
# 1  𪗨  崇開三臻入  3312-1,3339-1
# 2  啜  昌合三仙入  3513-2,3534-1
# 3  抾  溪開三之平  195-11,209-1
# 4  𣀔  滂合三元去  2601-5,2607-1
# 5  駛  生開三之去  2262-1,2262-2
# 6  縝  章開三眞上  1466-2,1466-11
# 7  觜  精開三支平  114-16,133-2

# %% [markdown]
# ## 有相同反切的小韻

# %%
pandas.read_sql_query('''SELECT 上字 || 下字 || '切' AS 反切,
group_concat(小韻全名) AS 小韻全名
FROM 廣韻小韻全
WHERE 上字 IS NOT NULL
GROUP BY 上字, 下字
HAVING count(*) > 1;''', conn)
# Out:
#     反切             小韻全名
# 0  丘弭切  1241跬小韻,1248企小韻
# 1  之少切  1678沼小韻,2769照小韻
# 2  古伯切  3618格小韻,3621虢小韻
# 3  古賣切  2453卦小韻,2491夬小韻
# 4  士免切  1653撰小韻,1663棧小韻
# 5  居乙切  3320曁小韻,3352訖小韻
# 6  烏浪切  2928盎小韻,2945汪小韻
# 7  芳万切  2601嬔小韻,2607𣀔小韻
# 8  苦蓋切  2446磕小韻,2534慨小韻

# %% [markdown]
# ## 名字相同的小韻

# %%
pandas.read_sql_query('''SELECT 小韻, 小韻全名
FROM 廣韻小韻全
GROUP BY 小韻
HAVING count(*) > 1;''', conn)
# Out:
#     小韻     小韻全名
# 0    㓼  1307㓼小韻
# 1    㔌  1030㔌小韻
# 2    㛂  1752㛂小韻
# 3    㟅  33㟅小韻
# 4    㪁  1154㪁小韻
# 5    㱡  964㱡小韻
# 6    䀴  1918䀴小韻
# 7    䁤  1282䁤小韻
# 8    䃔  40䃔小韻
# 9    䆀  1456䆀小韻
# 10   䟽  236䟽小韻
# 11   䫲  2019䫲小韻
# 12   䰖  1560䰖小韻
# 13   三  1090三小韻
# 14   且  245且小韻
# 15   中  3中小韻
# 16   些  801些小韻
# 17   企  1248企小韻
# 18   作  2360作小韻
# 19   侃  1558侃小韻
# 20   便  615便小韻
# 21   倗  1924倗小韻
# 22   倚  1212倚小韻
# 23   傍  856傍小韻
# 24   儑  3112儑小韻
# 25   兼  1129兼小韻
# 26   凝  960凝小韻
# 27   凭  951凭小韻
# 28   出  2243出小韻
# 29   分  459分小韻
# 30   剸  1651剸小韻
# 31   卒  3327卒小韻
# 32   吟  1063吟小韻
# 33   吹  98吹小韻
# 34   和  753和小韻
# 35   啜  2414啜小韻
# 36   啞  1770啞小韻
# 37   喊  2030喊小韻
# 38   圈  1646圈小韻
# 39   埯  2031埯小韻
# 40   堲  3304堲小韻
# 41   增  973增小韻
# 42   奔  496奔小韻
# 43   女  1335女小韻
# 44   奻  549奻小韻
# 45   妠  3114妠小韻
# 46   嬽  567嬽小韻
# 47   孨  2742孨小韻
# 48   少  1681少小韻
# 49   屯  442屯小韻
# 50   崽  335崽小韻
# 51   巉  1144巉小韻
# 52   巋  183巋小韻
# 53   巢  689巢小韻
# 54   差  120差小韻
# 55   從  57從小韻
# 56   徵  958徵小韻
# 57   恐  1181恐小韻
# 58   扮  1422扮小韻
# 59   掣  2401掣小韻
# 60   撰  1591撰小韻
# 61   操  723操小韻
# 62   擔  1089擔小韻
# 63   攤  1576攤小韻
# 64   敗  2495敗小韻
# 65   敲  696敲小韻
# 66   暴  2816暴小韻
# 67   朓  1668朓小韻
# 68   枕  1985枕小韻
# 69   棧  1597棧小韻
# 70   楚  1339楚小韻
# 71   榜  1835榜小韻
# 72   殑  963殑小韻
# 73   毀  1205毀小韻
# 74   汪  849汪小韻
# 75   沈  1050沈小韻
# 76   泥  314泥小韻
# 77   浜  892浜小韻
# 78   淙  86淙小韻
# 79   深  1054深小韻
# 80   湩  1187湩小韻
# 81   湫  1675湫小韻
# 82   潛  1117潛小韻
# 83   灑  1418灑小韻
# 84   烘  32烘小韻
# 85   焌  2629焌小韻
# 86   爲  89爲小韻
# 87   爹  802爹小韻
# 88   牝  1264牝小韻
# 89   狂  836狂小韻
# 90   猭  635猭小韻
# 91   瓦  1786瓦小韻
# 92   甚  1988甚小韻
# 93   生  884生小韻
# 94   省  1859省小韻
# 95   瞢  13瞢小韻
# 96   稱  962稱小韻
# 97   稴  2057稴小韻
# 98   積  2155積小韻
# 99   窒  3300窒小韻
# 100  等  1455等小韻
# 101  精  910精小韻
# 102  絮  2304絮小韻
# 103  綰  1579綰小韻
# 104  縛  2852縛小韻
# 105  縱  61縱小韻
# 106  翹  684翹小韻
# 107  聱  697聱小韻
# 108  能  397能小韻
# 109  脅  3156脅小韻
# 110  脞  762脞小韻
# 111  興  961興小韻
# 112  若  800若小韻
# 113  茁  3318茁小韻
# 114  荒  844荒小韻
# 115  華  773華小韻
# 116  著  2298著小韻
# 117  蓄  3215蓄小韻
# 118  蕝  2418蕝小韻
# 119  藏  858藏小韻
# 120  虚  237虚小韻
# 121  虥  559虥小韻
# 122  虺  349虺小韻
# 123  螼  1494螼小韻
# 124  行  887行小韻
# 125  衰  136衰小韻
# 126  要  676要小韻
# 127  見  2702見小韻
# 128  覘  1112覘小韻
# 129  親  408親小韻
# 130  詑  129詑小韻
# 131  論  497論小韻
# 132  諵  1140諵小韻
# 133  豻  508豻小韻
# 134  跪  1207跪小韻
# 135  蹱  58蹱小韻
# 136  載  2529載小韻
# 137  輕  920輕小韻
# 138  轟  901轟小韻
# 139  迎  886迎小韻
# 140  近  1511近小韻
# 141  遠  1516遠小韻
# 142  選  1652選小韻
# 143  邅  606邅小韻
# 144  重  56重小韻
# 145  野  1348野小韻
# 146  長  815長小韻
# 147  闞  2073闞小韻
# 148  頸  929頸小韻
# 149  飯  1529飯小韻
# 150  餧  1438餧小韻
# 151  饒  666饒小韻
# 152  鰥  555鰥小韻
# 153  𠊧  1880𠊧小韻
# 154  𡰝  570𡰝小韻
# 155  𤣆  402𤣆小韻
# 156  𥄎  3524𥄎小韻
# 157  𪉦  3121𪉦小韻
# 158  𪗨  3312𪗨小韻

# %% [markdown]
# ## 未收錄的反切上字

# %%
pandas.read_sql_query('''SELECT 上字, 小韻號, 音韻地位, 上字 || 下字 || '切' AS 反切
FROM 廣韻小韻全
WHERE 上字 NOT IN
(SELECT 字頭 FROM 廣韻字頭)
GROUP BY 上字;''', conn)
# Out:
#   上字   小韻號    音韻地位   反切
# 0  呂  76    來開二江平   呂江切
# 1  奇  2165  羣開三支B去  奇寄切
# 2  妳  332   孃開二佳平   妳佳切
# 3  姉  3529  精開三仙入   姉列切
# 4  姊  133   精開三支平   姊移切
# 5  查  3464  崇開二刪入   查鎋切
# 6  犲  2507  崇開二夬去   犲夬切
# 7  疏  146   生開三脂平   疏夷切
# 8  青  2059  清開四添上   青忝切

# %% [markdown]
# ## 未收錄的反切下字

# %%
pandas.read_sql_query('''SELECT 下字, 小韻號, 音韻地位, 上字 || 下字 || '切' AS 反切
FROM 廣韻小韻全
WHERE 下字 NOT IN
(SELECT 字頭 FROM 廣韻字頭)
GROUP BY 下字;''', conn)
# Out:
#    下字   小韻號    音韻地位   反切
# 0   候  3064  溪開一侯去   苦候切
# 1   劒  3158  明合三凡去   亡劒切
# 2   卧  2837  見合一戈去   古卧切
# 3   奇  107   溪開三支B平  去奇切
# 4   姊  1255  邪開三脂上   徐姊切
# 5   彦  2753  來開三仙去   連彦切
# 6   樣  2896  日開三陽去   人樣切
# 7   狶  1313  溪開三微上   袪狶切
# 8   笑  2771  影開三宵A去  於笑切
# 9   耗  2817  幫開一豪去   博耗切
# 10  葅  236   生開三魚平   所葅切
# 11  衛  2392  知合三祭去   陟衛切
# 12  賓  421   滂開三眞A平  匹賓切
# 13  賺  3167  孃開二咸去   尼賺切
# 14  閏  2574  章合三諄去   之閏切
# 15  顔  547   見開二刪平   古顔切
# 16  魂  500   滂合一魂平   普魂切

# %% [markdown]
# ## 長度大於 1 的字

# %%
pandas.read_sql_query('''SELECT 字頭, 解釋, 小韻全名,
音韻地位, 小韻內字序
FROM 廣韻字頭全
WHERE length(字頭) > 1;''', conn)
# Out:
#       字頭     解釋     小韻全名   音韻地位  小韻內字序
# 0  ⿱𥫗瀸    上同     576前小韻   從開四先平  6
# 1  ⿱⿰来攵正  俗      1883整小韻  章開三清上  2
# 2  ⿰隺犬    至也髙也   3276㱿小韻  溪開二江入  15
# 3  ⌸艹大雨   俗      3291七小韻  清開三眞入  7
# 4  ⿱入疌    織⿱入?疌  3817聶小韻  孃開三鹽入  4

# %%
conn.close()
